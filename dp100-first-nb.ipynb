# %% [markdown]
# This is an interface for Notebook Editor ..
# Notebook = Code + Output + documenttaion

# %%
print ("Welcome to Azure Machine Learning")
# Out:
# Welcome to Azure Machine Learning

# %%
print ("Welcome to Azure Machine Learning  and This is JupyterLab ...")
# Out:
# Welcome to Azure Machine Learning  and This is JupyterLab ...

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt


print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %% [markdown]
# These libraries are used for Data Processing, Machine Learning and Visualization ...

# %%
# !pip install seaborn

# %%
import seaborn as sns

print ("Seaborn Installed")
# Out:
# Seaborn Installed

# %%
from azureml.core import workspace

print (workspace.name, workspace.resource_group, workspace.location)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 from azureml.core import workspace
# ----> 3 print (workspace.name, workspace.resource_group, workspace.location)
#
# AttributeError: module 'azureml.core.workspace' has no attribute 'name'

# %%
from azureml.core import Workspace

ws = Workspace.from_config()

print (ws.name, ws.resource_group, ws.location)
# Out:
# ajit-dp100 ajit-rg centralindia

# %% [markdown]
# # LAB 1 --  Data Loading and Basic Exploration using Pandas

# %% [markdown]
# # Pandas -- Data Manipulation -- Data Loading and Exploration ..
#
# # Load Dataset, View Top Rows, Check Data Types, Summary statistics

# %%
import pandas as pd

df = pd.read_csv('diabetes.csv')

# %%
! ls
# Out:
# 'Untitled Folder'   Users   ajit_demo   diabetes.csv   dp100-first-nb.ipynb

# %%
df.head()

# Represents first five rows of your dataset
# Out:
#    PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0    1354778            0            171                      80
# 1    1147438            8             92                      93
# 2    1640031            7            115                      47
# 3    1883350            9            103                      78
# 4    1424119            1             85                      59
#
#    TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  Diabetic
# 0                34            23  43.509726          1.213191   21         0
# 1                47            36  21.240576          0.158365   23         0
# 2                52            35  41.511523          0.079019   23         0
# 3                25           304  29.582192          1.282870   43         1
# 4                27            35  42.604536          0.549542   22         0

# %%
df.info()

# Detect null values and data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PatientID               10000 non-null  int64
#  1   Pregnancies             10000 non-null  int64
#  2   PlasmaGlucose           10000 non-null  int64
#  3   DiastolicBloodPressure  10000 non-null  int64
#  4   TricepsThickness        10000 non-null  int64
#  5   SerumInsulin            10000 non-null  int64
#  6   BMI                     10000 non-null  float64
#  7   DiabetesPedigree        10000 non-null  float64
#  8   Age                     10000 non-null  int64
#  9   Diabetic                10000 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 781.4 KB

# %%
df.describe()

# Better statistical understanding
# Out:
#           PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# count  1.000000e+04  10000.00000   10000.000000            10000.000000
# mean   1.502122e+06      3.25580     107.850200               71.207500
# std    2.892868e+05      3.40572      31.920909               16.801478
# min    1.000038e+06      0.00000      44.000000               24.000000
# 25%    1.251672e+06      0.00000      84.000000               58.000000
# 50%    1.504394e+06      2.00000     105.000000               72.000000
# 75%    1.754608e+06      6.00000     129.000000               85.000000
# max    1.999997e+06     14.00000     192.000000              117.000000
#
#        TricepsThickness  SerumInsulin           BMI  DiabetesPedigree  \
# count       10000.00000  10000.000000  10000.000000      10000.000000
# mean           28.81760    139.243600     31.567022          0.400944
# std            14.50648    133.777919      9.804366          0.381463
# ...

# %%
df.shape

# To find out rows and colums in dataset
# Out:
# (10000, 10)

# %% [markdown]
# # It is used in EDA (Exploratory Data Analysis)
